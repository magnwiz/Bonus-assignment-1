# %% [markdown]
# ## Bonus assignment #1
#
# In this week's bonus assignment, we will be playing rock, paper, scissors. And we will be working on your date of birth.

# %% [markdown]
# **Assignment 1 - Rock, paper, scissors game!**
#
# The game is played by two players: we will call them the first player and the second player. These two players pick rock, paper or acissors and they reveal it at the same time. The winner is decided based on the rules in the picture below.
#
# Write a **function** named create_game that does the following:
#
# * Ask both players for their input choice (rock, paper or scissors). For this, use input() function.
# * Based on the players' choices, determine and print who wins the game (The first player wins, or the second player wins.). Note that when both players' choices are the same, it is a tie.
# * If the players' choices are something else than rock, paper or scissors, mention that this is invalid.

# %%
from IPython.core.display import Image

Image('Bonus_Assignment_Week1_image.png')

#source: https://www.pngitem.com/middle/ixowRJT_rock-paper-scissors-rules-hd-png-download/

# %% [markdown]
# **Assignment 2 - How many days till your birthday?**
#
# * Ask for user's input on their birth month (from 1 to 12) and birthday (from 1 to 31). Use input function for this.
# * Ask for today's month and day. Use input function for this too.
# * Write a function named calculate_birthday and calculate how many days left until the user's next birthday. Print the number days left. If the birthday has already passed for this year, then print 'You'll have to wait until next year for another birthday.' If the birthday is today, then print 'Happy birthday!'
#
# Note that you may take the number of days as 30 for every month, to make the assignment easier.
#
# Hint: Input function gives strings. So, you might have to convert them to integers.
